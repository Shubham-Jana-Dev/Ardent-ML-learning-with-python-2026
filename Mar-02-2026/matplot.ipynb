# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [1,2,3,4]
y = [5,6,7,8]

# %%
plt.plot(x,y)
plt.show(x,y)

# %%
a = [2,3,4,5,6]
y = []
for i in a:
    y.append(i**5)
y
# Out:
# [32, 243, 1024, 3125, 7776]

# %%
plt.plot(a,y)
plt.grid()
plt.title("My first graph in my mac. :)")
plt.show()

# %%
# Pyplot API
# Univariate - Numarical
data = {'salary': [1600,19000,25000,30000,35000,40000,50000,70000,90000,120000,150000]}
df = pd.DataFrame(data)
df.head()
# Out:
#    salary
# 0    1600
# 1   19000
# 2   25000
# 3   30000
# 4   35000
